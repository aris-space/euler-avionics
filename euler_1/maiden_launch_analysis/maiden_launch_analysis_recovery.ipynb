# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
sns.set(rc={'figure.figsize':(24, 13.5)}, font_scale = 2.7)

# %%
recovery = pd.read_csv('recovery-data/recovery-data.csv', index_col = 'Time')
telemetry = pd.read_csv('maiden_launch_combined_telemetry.csv', index_col='Time [s]')
print(recovery.shape)
print(telemetry.shape)
# Out:
# (91683, 36)
# (15112, 33)

# %%
combined = recovery.drop_duplicates().sort_index().reset_index()
combined.shape
# Out:
# (91683, 37)

# %%
t0 = 2278.8 # time of start of plot [s]
duration = 36 #32 # flight duration [s]
g = -9.81 # correct for gravity
combined['Time [s]'] = (combined['Time'])/1000 - t0
combined['Acceleration 1 [g]'] = (combined['Ay_IMU1'] / g)
combined['Acceleration 2 [g]'] = (combined['Ay_IMU2'] / g)
combined['Temperature [°C]'] = combined['T_SHT']
combined['Humidity [%]'] = combined['H_SHT']
#combined['Battery [V]'] = combined['battery_battery']/1000
combined['Pressure 1 [kPa]'] = combined['P_BARO1']/1000
combined['Pressure 2 [kPa]'] = combined['P_BARO2']/1000

gyro_labels = ['Gx_IMU1','Gy_IMU1','Gz_IMU1','Gx_IMU2','Gy_IMU2','Gz_IMU2']
for label in gyro_labels:
    combined[label] /= 2

# %%
#convert to gs
fmt_acc = lambda x: x / 1024
#convert to degrees per second
fmt_gyro = lambda x: x / 16.4
dim3 = lambda x : [x + '_' + s for s in ['x', 'y', 'z']]

telemetry[dim3('Acceleration')] = telemetry[dim3('sb_data_acc')].apply(pd.to_numeric).apply(fmt_acc)
telemetry[dim3('Gyro')] = telemetry[dim3('sb_data_gyro')].apply(pd.to_numeric).apply(fmt_gyro)

# %%
# Some options
show_telemetry = True     # whether to display telemetry data points
show_flight_events = True # whether to display ignition, burnout, apogee
show_actuation = True     # whether to display airbrake actuation areas

t_ignition = 1.55 # time of ignition [s]
t_burnout = 5.4  # time of burnout [s]
t_apogee = combined['Time [s]'][pd.Series.argmin(combined['Pressure 1 [kPa]'])] # time of apogee (min pressure) [s]

def plot_events(plt):
    if show_flight_events:
        plt.axvline(x=t_ignition, color='k')
        plt.axvline(x=t_burnout, color='k')
        plt.axvline(x=t_apogee, color='k')
    if show_actuation:
        plt.axvspan(6.8, 7.5, color='b', alpha=0.2)
        plt.axvspan(8.7, 9.8, color='b', alpha=0.2)
        plt.axvspan(11.1, 16, color='b', alpha=0.2)

# %%
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'Acceleration 1 [g]', label="Recovery 1")
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'Acceleration 2 [g]', label="Recovery 2")

if show_telemetry:
    plt = sns.scatterplot(data = telemetry.reset_index(), x = 'Time [s]', y = 'Acceleration_z', color = 'black', edgecolor='gray', label='Telemetry')

plot_events(plt)

plt.set_ylabel('Vertical Acceleration [g]')
plt.set_xlabel('Time [s]')
plt.set_xlim(0, duration)
print(f"Max acceleration: {np.max(combined['Acceleration 1 [g]'])} g")
print(f"Min acceleration: {np.min(combined['Acceleration 1 [g]'])} g")
# Out:
# Max acceleration: 7.007135575942915 g
# Min acceleration: -1.63914373088685 g

# %%
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'Ax_IMU1', label='a_x1')
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'Ax_IMU2', label='a_x2')
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'Az_IMU1', label='a_z1')
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'Az_IMU2', label='a_z2')
plot_events(plt)

plt.set_ylabel('Horizontal Acceleration [m/s^2]')
plt.set_xlabel('Time [s]')
plt.set_xlim(0, duration)
plt.legend(loc='upper right')

# %%
for label in gyro_labels:
    plt = sns.lineplot(data = combined, x = 'Time [s]', y = label, label=label)

if show_telemetry:
    plt = sns.scatterplot(data = telemetry.reset_index(), x = 'Time [s]', y = 'Gyro_z', color = 'black', edgecolor='gray', label='Telemetry')

plot_events(plt)

plt.set_title(f'Gyroscope data IMU 1 & 2')
plt.set_ylabel('Rotation [dps]')
plt.set_xlabel('Time [s]')
plt.set_xlim(0, duration)

plt.legend(loc='upper center')

# %%
#plt = sns.scatterplot(data = combined.reset_index(), x = 'Time [s]', y = 'Pressure [kPa]', color = 'black', edgecolor='gray')
plt = sns.lineplot(data = combined.reset_index(), x = 'Time [s]', y = 'Pressure 1 [kPa]', label="Recovery 1")
plt = sns.lineplot(data = combined.reset_index(), x = 'Time [s]', y = 'Pressure 2 [kPa]', label="Recovery 2")

plot_events(plt)

if show_telemetry:
    plt = sns.scatterplot(data = telemetry.reset_index(), x = 'Time [s]', y = 'Pressure [kPa]', color = 'black', edgecolor='gray', label='Telemetry')

plt.set_ylabel('Pressure [kPa]')
plt.set_xlabel('Time [s]')
plt.set_xlim(0, duration)
# Out:
# (0, 36)

# %%
#plt = sns.scatterplot(data = combined, x = 'Time [s]', y = 'Battery [V]', color = 'black', edgecolor='gray')
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'V_BAT1')
plt = sns.lineplot(data = combined, x = 'Time [s]', y = 'V_BAT2')
plt.set_ylabel('Battery Voltage [V]')
plt.set_xlabel('Time [s]')
#plt.set_ylim(-1, 2)
plt.set_xlim(0, duration)

# %%
plt = sns.lineplot(data = combined.reset_index(), x = 'Time [s]', y = 'Humidity [%]')
plt.set_ylabel('Humidity [%]')
plt.set_xlabel('Time [s]')
plt.set_xlim(0, duration)

print(f"Max humidity: {np.max(combined['Humidity [%]'])}%")
print(f"Min humidity: {np.min(combined['Humidity [%]'])}%")

# %%
plt = sns.lineplot(data = combined.reset_index(), x = 'Time [s]', y = 'Temperature [°C]')
plt.set_ylabel('Ambient Temperature [°C]')
plt.set_xlabel('Time [s]')
plt.set_xlim(0, duration)

print(f"Max temperature: {np.max(combined['Temperature [°C]'])} °C")
print(f"Min temperature: {np.min(combined['Temperature [°C]'])} °C")
